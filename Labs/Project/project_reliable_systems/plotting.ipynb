# %%
TMR_02 = [0, 773, 1555, 2316, 3067, 3868]
TMR_05 = [0, 3951, 7908, 11_996, 16_037, 20_213]
TMR_1 = [0, 11830, 23661, 35557, 47488, 59397]

clock_cycles = [0, 20_00, 40_00, 60_00, 80_00, 10_000]

# %%
# plot the data in 3 seperate scatter plots
import matplotlib.pyplot as plt
plt.plot(clock_cycles, TMR_02, '-o', label='Error Probability: 0.2')
plt.plot(clock_cycles, TMR_05, '-o', label='Error Probability: 0.5')
plt.plot(clock_cycles, TMR_1, '-o', label='Error Probability: 1')

plt.xlabel('Num of clock cycles')
plt.ylabel('Number of errors')
plt.legend()
plt.show()
